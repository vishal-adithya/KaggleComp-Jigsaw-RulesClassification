# %% [markdown]
# # Kaggle Comp : Jigsaw Rules Classification (Raw Test Data preprocessing notebook)

# %% [markdown]
# ### Dependencies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random
import json
import os

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### EDA

# %%
df = pd.read_csv(os.path.join("Data", "test.csv"))
df.set_index('row_id', inplace=True)
df.head()
# Out:
#                                                      body  \
# row_id
# 2029    NEW RAP GROUP 17. CHECK US OUT https://soundcl...
# 2030    Make your life comfortable. Get up to 15% Disc...
# 2031    Kickin' ass and selling underwear!\nJust made ...
# 2032     watch  hooters  best  therein  http://clickan...
# 2033     bitches  for free  at this point  show all  h...
#
#                                                      rule        subreddit  \
# row_id
# 2029    No Advertising: Spam, referral links, unsolici...      hiphopheads
# 2030    No legal advice: Do not offer or request legal...        AskReddit
# 2031    No Advertising: Spam, referral links, unsolici...         gonewild
# 2032    No Advertising: Spam, referral links, unsolici...  personalfinance
# 2033    No Advertising: Spam, referral links, unsolici...   Showerthoughts
#
#                                        positive_example_1  \
# row_id
# 2029    Hey, guys, just wanted to drop in and invite y...
# 2030    Get a lawyer and get the security camera foota...
# 2031    Good story my friend. Check out my blog at  ht...
# 2032    Earn 50,000 bonus points with Chase Sapphire P...
# 2033    code free tyrande --->>> [Imgur](http://i.imgu...
#
#                                        positive_example_2  \
# row_id
# 2029    Cum Swallowing Hottie Katrina Kaif Cartoon Xvi...
# 2030    That isn't drastic. You tried reaching out to ...
# 2031    If you know what exactly you need then you don...
# 2032    Cool, front page! I made this print along with...
# 2033    My trade link\nhttps://steamcommunity.com/trad...
#
#                                        negative_example_1  \
# row_id
# 2029    SD Stream Eng - [Chelsea TV USA](http://soccer...
# 2030    So what are you going to do with the insurance...
# 2031    CENTIPEDES\n\nSOME BASED PATRIOTS HAVE CREATED...
# 2032    [Full HD Movie Online Free](http://www.flickma...
# 2033    **HD** [ mio Stadium 102 HD](http://www.genti....
#
#                                        negative_example_2
# row_id
# 2029    HD Streams: |[ENG HD Stoke vs Manchester Unite...
# 2030    It's just for Austria & Germany. If you still ...
# 2031    [So great! Thanks for sharing.](http://www.che...
# 2032    * Karambit Black Pearl\n* 0.02137822 Float (un...
# 2033    Infographics is an incredible method for showi...

# %%
df.describe()
# Out:
#                                                      body  \
# count                                                  10
# unique                                                 10
# top     NEW RAP GROUP 17. CHECK US OUT https://soundcl...
# freq                                                    1
#
#                                                      rule  subreddit  \
# count                                                  10         10
# unique                                                  2          9
# top     No Advertising: Spam, referral links, unsolici...  AskReddit
# freq                                                    9          2
#
#                                        positive_example_1  \
# count                                                  10
# unique                                                  9
# top     code free tyrande --->>> [Imgur](http://i.imgu...
# freq                                                    2
#
#                                        positive_example_2  \
# count                                                  10
# unique                                                 10
# top     Cum Swallowing Hottie Katrina Kaif Cartoon Xvi...
# freq                                                    1
#
#                                        negative_example_1  \
# count                                                  10
# unique                                                  9
# top     [Full HD Movie Online Free](http://www.flickma...
# freq                                                    2
#
#                                        negative_example_2
# count                                                  10
# unique                                                 10
# top     HD Streams: |[ENG HD Stoke vs Manchester Unite...
# freq                                                    1

# %%
records = []

for _,row in df.iterrows():
    body = row["body"]
    rule = row["rule"]
    sub = row["subreddit"]
    ex1 = row["positive_example_1"]
    ex2 = row["positive_example_2"]
    ex3 = row["negative_example_1"]
    ex4 = row["negative_example_2"]
    instruction = "You are a moderation assistant. Decide if the following Reddit comment violates the given rule. Use the subreddit context and provided examples to guide your judgment. Answer strictly with 1 (if it violates) or 0 (if it does not)."
    prompt = f"{instruction},Input: Body: {body},Subreddit: {sub},Positive Examples: {ex1}, {ex2}, Negative Examples: {ex3}, {ex4}"
    records.append({"text":prompt})
random.shuffle(records)
records[:5]
# Out:
# [{'text': "You are a moderation assistant. Decide if the following Reddit comment violates the given rule. Use the subreddit context and provided examples to guide your judgment. Answer strictly with 1 (if it violates) or 0 (if it does not).,Input: Body: Free paypal cards here!! https://www.pointsprizes.com/ref/13226,Subreddit: pics,Positive Examples: she will come your home open her legs with  and  you http://sh.ors.it/PALI2, Old and young  your girl-next-door make sex with  at this point tight ass! http://42.herber.pl/535lc, Negative Examples: i think  the conjuring 2 is not bad movie ,The movie was awesome! watch full movie [here](http://www.megasharenow.com/the-conjuring-2-2016-watch-online-free-megashare), wow, she's so beautyful\n>[Sakura Vietnam](http://skr.vn/sakurabeauty)"},
#  {'text': "You are a moderation assistant. Decide if the following Reddit comment violates the given rule. Use the subreddit context and provided examples to guide your judgment. Answer strictly with 1 (if it violates) or 0 (if it does not).,Input: Body:  watch  hooters  best  therein  http://clickand.co/5agw-,Subreddit: personalfinance,Positive Examples: Earn 50,000 bonus points with Chase Sapphire Preferred®. Learn more at  https://applynow.chase.com/FlexAppWeb/renderApp.do?PID=CFFD2&SPID=FHRJ&CELL=600V&MSC=1532571015 #sponsored, Cool, front page! I made this print along with a lot of other science and spaced themed stuff you can find here: http://2046printshop.com/\nIf you really want the Apollo print you can PM me, if I get enough requests I'll make another run of it., Negative Examples: [Full HD Movie Online Free](http://www.flickmaza.com/), * Karambit Black Pearl\n* 0.02137822 Float (unfortunate corner)\n* Non-Duped\n* Screenshot - http://imgur.com/a/Zvy5D\n* Metjm - http://s.metjm.net/0XymKVi.jpg\n* B/O - 500+ keys (Very Negotiable)\n* PC (500 keys) - https://imgur.com/a/5IWM3\n* C/O (485) - https://imgur.com/a/zgexV\n* My steam Acc. - https://steamcommunity.com/id/OfficialSnuffy/\n* Send me an offer here:\n* https://steamcommunity.com/tradeoffer/new/?partner=154014229&token=npsf8rwb"},
#  {'text': "You are a moderation assistant. Decide if the following Reddit comment violates the given rule. Use the subreddit context and provided examples to guide your judgment. Answer strictly with 1 (if it violates) or 0 (if it does not).,Input: Body: Kickin' ass and selling underwear!\nJust made my account last night. You guys should do the same and follow up on my photos and more 😘\n\n\n[find me here❤️](http://www.pantydeal.com/member/Ineffable) ,Subreddit: gonewild,Positive Examples: Good story my friend. Check out my blog at  http://www.ink2quill.com/, If you know what exactly you need then you don't needa prescription. You can buy it online. I buy every medication I need during last 3 years online and can recommend it. http://cheapmarketmeds.com/ is a pharmacy where you can find high-quality Wellbutrin., Negative Examples: CENTIPEDES\n\nSOME BASED PATRIOTS HAVE CREATED A BASED NEW SUB FOR THE_DON CONTENT\n\nhttps://www.reddit.com/r/The_Uncensored_Donald/\n\nIF YOU WANT FRESH CONTENT, KEK BLESSINGS AND MORE HIGH ENERGY DELIVERED TO YOU PAY THEM A VISIT AND SHITPOST THERE FOR STICKING IT TO A CERTAIN EDITING CANNIBAL, [So great! Thanks for sharing.](http://www.cheapsexynightgirls.com/2014/03/zoya-independent-call-girls-in-dubai.html)"},
#  {'text': 'You are a moderation assistant. Decide if the following Reddit comment violates the given rule. Use the subreddit context and provided examples to guide your judgment. Answer strictly with 1 (if it violates) or 0 (if it does not).,Input: Body: must be watch movie https://sites.google.com/site/greatescape1963xx/-the-avengers-2012-hd-movie,Subreddit: movies,Positive Examples:  see  there  hooters  sweet  http://url.t.aylor.de/2176b, Sign up with my link and get $1,000 of free processing! Thanks!\n\nhttps://squareup.com/i/DAE7E171, Negative Examples: The fact that there are pro and cons to everything...thats why i created this website http://www.proandkon.com/, Oh that\'s interesting. You should check out my instagram page "dailyetymology" for more cool etymology!'},
#  {'text': "You are a moderation assistant. Decide if the following Reddit comment violates the given rule. Use the subreddit context and provided examples to guide your judgment. Answer strictly with 1 (if it violates) or 0 (if it does not).,Input: Body: WIN A SAMSUNG SMARTWATCH!\n\nhttp://www.innomdlelab.com/?kid=ARSRE\n\nEnter your email adress on the following link, and then \nverify your vote in your email inbox. This way you'll have a \nchance to win a smartwatch or a smarstrap! (and you can help me too),Subreddit: AskReddit,Positive Examples: [ENJOY 50,000 BONUS POINTS after $4,000 spent on purchases in the first 3 months from account opening Chase Sapphire Preferred\\(R\\) Credit Card That's $625 toward airfare or hotels when you redeem through Chase Ultimate Rewards](https://applynow.chase.com/FlexAppWeb/renderApp.do?SPID=FH8L&CELL=600S&AFFID=&CLICK=&CID=&PROMO=DF01&MSC=1528652083), We have high quality Canadian Polymer banknotes, USD bills, Euro notes for sell at good rates. We make the unusable usable. Send a private message if interested for more details or contact me through the wickr app on google play or Apple Store.\n\nwickr: armando241 \n, Negative Examples: i was on the same ios and try this jailbreak method so much easier if it helps pass it along :) https://youtu.be/sXkcOtRsF3M\nyoull only need a pc or mac to backup ur info, but not for the actual jb , We're streaming Pokemon Veitnamese Crystal RIGHT NOW, come watch https://www.twitch.tv/adandyguyinspace55."}]

# %%
with open(os.path.join("Preprocessed_Data","test.jsonl"),"w") as file:
    for record in records:
        file.write(json.dumps(record)+"\n")
